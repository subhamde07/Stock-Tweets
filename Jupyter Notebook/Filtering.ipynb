# %%
import numpy as np
import pandas as pd
import nselib
from nselib import capital_market

# %%
nselib.trading_holiday_calendar()
df = capital_market.bhav_copy_with_delivery("01-05-2024")
df.head()
# Out:
#        SYMBOL SERIES  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  CLOSE_PRICE  \
# 0  1018GS2026     GS      118.65      118.65     112.00       112.44
# 1   20MICRONS     EQ      174.00      176.50     169.50       171.75
# 2  21STCENMGM     BE       48.95       50.90      48.95        50.65
# 3      360ONE     EQ      792.10      793.00     774.40       784.05
# 4   3IINFOLTD     EQ       39.85       40.65      38.80        38.95
#
#    PREV_CLOSE  TTL_TRD_QNTY  TURNOVER_LACS  NO_OF_TRADES DELIV_QTY DELIV_PER  \
# 0      113.00           108           0.12             6       107     99.07
# 1      172.65        302999         526.18          9418    139309     45.98
# 2       49.95         25100          12.71            29         -         -
# 3      789.25        424089        3322.94         24654    193558     45.64
# 4       39.65       1117963         439.55          5158    740392     66.23
#
#          DATE1
# 0  30-Apr-2024
# 1  30-Apr-2024
# 2  30-Apr-2024
# 3  30-Apr-2024
# 4  30-Apr-2024

# %%
df.columns.to_list()
# Out:
# ['SYMBOL',
#  'SERIES',
#  'OPEN_PRICE',
#  'HIGH_PRICE',
#  'LOW_PRICE',
#  'CLOSE_PRICE',
#  'PREV_CLOSE',
#  'TTL_TRD_QNTY',
#  'TURNOVER_LACS',
#  'NO_OF_TRADES',
#  'DELIV_QTY',
#  'DELIV_PER',
#  'DATE1']

# %%
df['DELIV_PER'] = pd.to_numeric(df['DELIV_PER'], errors='coerce')
condition = (df['SERIES'] == 'EQ') & (df['TURNOVER_LACS'] > 100) & (df['DELIV_PER'] > 85.00)
new_df = df[condition]
new_df
# Out:
#           SYMBOL SERIES  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  CLOSE_PRICE  \
# 112       AGSTRA     EQ       77.45       77.45      75.00        75.70
# 254        AURUM     EQ      155.00      155.45     153.00       155.45
# 350         BFSI     EQ       22.80       22.80      22.11        22.18
# 384     BLUEDART     EQ     6275.90     6327.95    6221.00      6311.30
# 494    COMMOIETF     EQ       89.44       89.44      88.15        88.53
# 644   EBBETF0430     EQ     1393.85     1393.85    1342.00      1353.61
# 646   EBBETF0433     EQ     1108.22     1109.90    1104.05      1107.38
# 694         ERIS     EQ      895.45      899.40     882.35       895.95
# 832   GOLDETFADD     EQ       75.03       75.03      70.35        71.29
# 839        GOPAL     EQ      322.00      323.40     318.00       319.75
# 873          GSS     EQ      139.95      139.95     134.80       135.85
# 922   HDFCPVTBAN     EQ       24.68       25.01      24.23        24.66
# 1030    ICICIB22     EQ      110.00      110.00     107.00       107.22
# 1332    KPIGREEN     EQ     1808.40     1808.40    1808.40      1808.40
# 1394   LIQUIDADD     EQ     1005.99     1007.24    1005.99      1007.23
# 1396  LIQUIDCASE     EQ      101.58      103.41      98.85       101.93
# 1449    MAHKTECH     EQ       12.96       13.03      12.81        12.97
# 1609       MVGJL     EQ      254.35      254.35     246.65       247.50
# 1687      NIFTY1     EQ      246.99      251.55     243.62       245.11
# 1695     NIITMTS     EQ      511.40      517.45     495.50       499.70
# 2101   SDL26BEES     EQ      123.45      123.45     120.10       120.48
# 2123    SETFGOLD     EQ       64.39       64.39      62.65        62.82
