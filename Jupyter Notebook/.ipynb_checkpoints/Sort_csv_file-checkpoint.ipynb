# %%
import pandas as pd

# This code only Checking for read and print CSV file..... Not necessary
# Read the CSV file into a pandas DataFrame 
df = pd.read_csv('03-04-2024_data.csv')
df
# Out:
#         SYMBOL SERIES  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  CLOSE_PRICE  \
# 0      63MOONS     EQ      441.65      441.65     441.65       441.65
# 1        AAVAS     EQ     1420.00     1424.95    1391.00      1395.55
# 2   BANKETFADD     EQ       47.15       48.06      47.15        47.95
# 3   BANKNIFTY1     EQ      485.26      487.55     483.01       486.98
# 4        CREST     EQ      410.40      411.00     403.55       406.55
# 5   EBBETF0425     EQ     1199.60     1199.60    1195.02      1196.14
# 6   EBBETF0433     EQ     1107.07     1201.01    1107.07      1156.57
# 7         EMIL     EQ      209.95      213.00     204.20       208.55
# 8      ESILVER     EQ       78.47       79.98      78.00        79.25
# 9   GOLDETFADD     EQ       68.32       69.20      68.03        68.90
# 10   GOLDSHARE     EQ       60.00       60.00      58.75        58.90
# 11    GTLINFRA     EQ        1.75        1.75       1.70         1.75
# 12     IPCALAB     EQ     1240.00     1240.00    1215.85      1224.35
# 13        IZMO     EQ      285.00      298.00     280.10       298.00
# 14      KERNEX     EQ      579.90      604.45     565.00       604.45
# 15  LIQUIDCASE     EQ      101.46      101.46     101.44       101.45
# 16   LIQUIDSBI     EQ      999.99     1000.01     999.99      1000.01
# 17     LOWVOL1     EQ       18.78       19.14      18.52        18.63
# 18     MEDANTA     EQ     1329.05     1349.00    1320.00      1337.95
# 19  METROBRAND     EQ     1104.75     1123.40    1091.50      1095.60
# 20    MOREALTY     EQ       97.00       97.00      92.76        92.87
# 21         NDL     EQ       35.45       37.25      34.75        37.00
# 22      NIFTY1     EQ      242.52      245.95     241.09       243.10
# 23     NIITMTS     EQ      520.40      525.00     512.70       520.95
# 24   PRIMESECU     EQ      181.80      184.05     178.10       180.50
# 25     PSUBANK     EQ      709.45      729.99     705.31       724.90
# 26   QGOLDHALF     EQ       59.19       59.19      58.22        58.58
# 27  ROLEXRINGS     EQ     1840.65     1870.00    1810.05      1854.15
# 28   SETFNIF50     EQ      234.79      235.93     234.00       234.92
# 29    SHREECEM     EQ    26601.00    26743.30   26285.10     26354.30
# 30    SMALLCAP     EQ       44.94       45.36      44.70        45.30
# 31   SURANASOL     EQ       42.00       42.45      41.00        42.45
# 32   SWELECTES     EQ     1104.75     1104.75    1104.75      1104.75
# 33      TIMKEN     EQ     2930.00     2992.05    2913.90      2982.95
# 34  VSTTILLERS     EQ     3288.75     3343.95    3267.85      3296.40
# 35    WESTLIFE     EQ      804.45      821.40     800.10       809.15
#
#     PREV_CLOSE  TTL_TRD_QNTY  TURNOVER_LACS  NO_OF_TRADES  DELIV_QTY  \
# 0       420.65         32834         145.01           285      32834
# 1      1415.45        425529        5981.45         19734     369277
# 2        47.84        740022         355.40           148     735634
# 3       485.62        346318        1685.34           385     333622
# 4       406.40        164628         669.85           755     154908
# 5      1196.00         14156         169.39           770      13943
# 6      1110.06         10732         123.93           112      10581
# 7       209.10       1200645        2505.66          7657    1055973
# 8        78.36        256422         203.17           328     248608
# 9        68.32        391073         270.27           180     388252
# 10       58.60       4824327        2838.82          1189    4773852
# 11        1.70      13838352         242.12          3314   13617769
# 12     1233.55       1653542       20228.47         20435    1406622
# 13      283.85         63111         185.98          1513      55366
# 14      575.70         27096         161.17           601      23330
# 15      101.43       4109934        4169.82          7328    4054749
# 16     1000.01         19502         195.02            65      19472
# 17       18.78       2003997         374.41           642    1963076
# 18     1331.65        838420       11259.98         18433     796939
# 19     1102.75        719970        7982.58         11517     645724
# 20       95.31        283145         264.55          3902     259907
# 21       35.50       1003640         369.06          1129     854533
# 22      242.53        886491        2153.80          1572     856710
# 23      520.30        373687        1932.73          5430     326038
# 24      181.75        220024         397.41          1387     204794
# 25      709.45        252549        1787.03          1441     222927
# 26       58.19        468690         274.58           639     437754
# 27     1824.35        151576        2778.78          5056     135541
# 28      235.33        759665        1788.74          3117     731526
# 29    26532.90        150756       39891.20         14690     133688
# 30       44.72       1057347         476.85          2464     950170
# 31       38.60        590373         249.99          3663     533448
# 32     1052.15         15986         176.61           345      15985
# 33     2931.25        133875        3939.20          5432     118489
# 34     3288.75         48550        1595.41          1816      43940
# 35      803.65        854639        6901.10          7305     800620
#
#     DELIV_PER        DATE1
# 0      100.00  03-Apr-2024
# 1       86.78  03-Apr-2024
# 2       99.41  03-Apr-2024
# 3       96.33  03-Apr-2024
# 4       94.10  03-Apr-2024
# 5       98.50  03-Apr-2024
# 6       98.59  03-Apr-2024
# 7       87.95  03-Apr-2024
# 8       96.95  03-Apr-2024
# 9       99.28  03-Apr-2024
# 10      98.95  03-Apr-2024
# 11      98.41  03-Apr-2024
# 12      85.07  03-Apr-2024
# 13      87.73  03-Apr-2024
# 14      86.10  03-Apr-2024
# 15      98.66  03-Apr-2024
# 16      99.85  03-Apr-2024
# 17      97.96  03-Apr-2024
# 18      95.05  03-Apr-2024
# 19      89.69  03-Apr-2024
# 20      91.79  03-Apr-2024
# 21      85.14  03-Apr-2024
# 22      96.64  03-Apr-2024
# 23      87.25  03-Apr-2024
# 24      93.08  03-Apr-2024
# 25      88.27  03-Apr-2024
# 26      93.40  03-Apr-2024
# 27      89.42  03-Apr-2024
# 28      96.30  03-Apr-2024
# 29      88.68  03-Apr-2024
# 30      89.86  03-Apr-2024
# 31      90.36  03-Apr-2024
# 32      99.99  03-Apr-2024
# 33      88.51  03-Apr-2024
# 34      90.50  03-Apr-2024
# 35      93.68  03-Apr-2024

# %%
def sort_csv_by_delivery_percentage(csv_file):
    try:
        df = pd.read_csv(csv_file)

        # Sort the DataFrame based on the DELIV_PER column in descending order
        df_sorted = df.sort_values(by='DELIV_PER', ascending=False)

        # Select only the 'SYMBOL' and 'DELIV_PER' columns
        df_sorted_subset = df_sorted[['SYMBOL', 'DELIV_PER']]

        # df_sorted_subset

        # Check if the DataFrame has at least 15 rows
        if len(df_sorted_subset) >= 15:
            # Print only the first 15 rows
            print(df_sorted_subset.head(15))
        else:
            # Print all rows if there are fewer than 15 rows
            print(df_sorted_subset)

        print('CSV file with selected columns sorted in descending order and first 15 rows printed successfully!')

    except FileNotFoundError:
        print(f"Error: CSV file '{csv_file}' not found. Please check the file path.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
# Replace with your actual CSV file path
csv_file = "/home/subhamde/Desktop/Final Year Project/Stock-Tweets/Data/03-04-2024_data.csv"
sort_csv_by_delivery_percentage(csv_file)
# Out:
#         SYMBOL  DELIV_PER
# 0      63MOONS     100.00
# 32   SWELECTES      99.99
# 16   LIQUIDSBI      99.85
# 2   BANKETFADD      99.41
# 9   GOLDETFADD      99.28
# 10   GOLDSHARE      98.95
# 15  LIQUIDCASE      98.66
# 6   EBBETF0433      98.59
# 5   EBBETF0425      98.50
# 11    GTLINFRA      98.41
# 17     LOWVOL1      97.96
# 8      ESILVER      96.95
# 22      NIFTY1      96.64
# 3   BANKNIFTY1      96.33
# 28   SETFNIF50      96.30
# CSV file with selected columns sorted in descending order and first 15 rows printed successfully!
